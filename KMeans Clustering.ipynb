# %% [markdown]
# # **MARKET SEGMENTATION**

# %% [markdown]
# ## **Import the relevant libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv('C:\\Users\\HP\\Downloads\\3.12. Example.csv')
data.head()
# Out:
#    Satisfaction  Loyalty
# 0             4    -1.33
# 1             6    -0.28
# 2             5    -0.99
# 3             7    -0.29
# 4             4     1.06

# %% [markdown]
# ## Plot the features

# %%
plt.scatter(data['Satisfaction'], data['Loyalty'])
plt.xlabel('Satisfaction')
plt.ylabel('Loyalty')
# Out:
# Text(0, 0.5, 'Loyalty')

# %% [markdown]
# ## Select the features

# %%
x = data.copy()

# %% [markdown]
# ## Standardize the features

# %%
scale = StandardScaler()
x_scaled = scale.fit_transform(x)

# %% [markdown]
# ## Determining the number of clusters (The Elbow method)

# %%
wcss = []
for i in range(1, 10):
    kmeans = KMeans(i, random_state=42)
    kmeans.fit(x_scaled)
    wcss_iter = kmeans.inertia_
    wcss.append(wcss_iter)

wcss
# Out:
# [59.999999999999986,
#  30.35236058808774,
#  18.12965944606323,
#  10.247181805928422,
#  7.792695153937187,
#  6.586212092192188,
#  6.173493205927985,
#  4.927070857759043,
#  3.951668467413593]

# %% [markdown]
# ## OR

# %%
wcss2 = [KMeans(i, random_state=42).fit(x_scaled).inertia_ for i in range(1, 10)]
wcss2
# Out:
# [59.999999999999986,
#  30.35236058808774,
#  18.12965944606323,
#  10.247181805928422,
#  7.792695153937187,
#  6.586212092192188,
#  6.173493205927985,
#  4.927070857759043,
#  3.951668467413593]

# %% [markdown]
# ## Plotting the elbow method using wcss

# %%
plt.plot(range(1, 10), wcss, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Within-Clusters Sum of Squares')
plt.title('The Elbow Method', size=15)
# Out:
# Text(0.5, 1.0, 'The Elbow Method')

# %% [markdown]
# ## Clustering

# %%
kmeans_new = KMeans(4, random_state=42)
kmeans_new.fit(x_scaled)
clusters = x.copy()
clusters['cluster_pred'] = kmeans_new.fit_predict(x_scaled)
clusters.head()
# Out:
#    Satisfaction  Loyalty  cluster_pred
# 0             4    -1.33             2
# 1             6    -0.28             3
# 2             5    -0.99             2
# 3             7    -0.29             3
# 4             4     1.06             0

# %% [markdown]
# ## Plotting the clusters

# %%
plt.scatter(clusters['Satisfaction'], clusters['Loyalty'], c=clusters['cluster_pred'], cmap='rainbow')
plt.xlabel('Satisfaction')
plt.ylabel('Loyalty')
plt.title('Customer Satisfactory and Loyalty Level')
# Out:
# Text(0.5, 1.0, 'Customer Satisfactory and Loyalty Level')

# %%
def silhouette_scorer(estimator, x_scaled):
    cluster_labels = estimator.fit_predict(x_scaled)
    return silhouette_score(x_scaled, cluster_labels)

# %%
kmeans_7 = KMeans(random_state=42)
param_grid = {
    'n_clusters' : np.arange(4, 7),
    'init' : ['k-means++', 'random'],
    'n_init' : [10, 20, 30],
    'max_iter' : [300, 400, 500]
}

# %%
gridsearch = GridSearchCV(estimator=kmeans_7, param_grid=param_grid, cv=5, scoring=silhouette_scorer)
gridsearch.fit(x_scaled)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
# ...
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 980, in _score
#     scores = scorer(estimator, X_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_4348\3251892470.py", line 3, in silhouette_scorer
#     return silhouette_score(x_scaled, cluster_labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 140, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 297, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 37, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 6. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.36500209 0.36500209 0.36500209 0.18686571 0.18686571 0.18686571
#         nan        nan        nan 0.36500209 0.36500209 0.36500209
#  0.18686571 0.18686571 0.18686571        nan        nan        nan
#  0.36500209 0.36500209 0.36500209 0.18686571 0.18686571 0.18686571
#         nan        nan        nan 0.36500209 0.36500209 0.36500209
#  0.18686571 0.18686571 0.18686571        nan        nan        nan
#  0.36500209 0.36500209 0.36500209 0.18686571 0.18686571 0.18686571
#         nan        nan        nan 0.36500209 0.36500209 0.36500209
#  0.18686571 0.18686571 0.18686571        nan        nan        nan]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=KMeans(random_state=42),
#              param_grid={'init': ['k-means++', 'random'],
#                          'max_iter': [300, 400, 500],
#                          'n_clusters': array([4, 5, 6]),
#                          'n_init': [10, 20, 30]},
#              scoring=<function silhouette_scorer at 0x000001DDB39DE3E0>)

# %%
gridsearch.best_params_
# Out:
# {'init': 'k-means++', 'max_iter': 300, 'n_clusters': 4, 'n_init': 10}

# %%
gridsearch.best_score_
# Out:
# 0.36500209162165903
